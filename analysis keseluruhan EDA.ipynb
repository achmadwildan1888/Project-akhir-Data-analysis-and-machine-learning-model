# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0  0           158023  L. Messi           31
# 1  1           20801   Cristiano Ronaldo  33
# 2  2           190871  Neymar Jr          26
# 3  3           193080  De Gea             27
# 4  4           192985  K. De Bruyne       27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png  Argentina
# 1  https://cdn.sofifa.org/players/4/19/20801.png   Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png  Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png  Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png  Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png  94       94
# 1  https://cdn.sofifa.org/flags/38.png  94       94
# 2  https://cdn.sofifa.org/flags/54.png  92       93
# 3  https://cdn.sofifa.org/flags/45.png  91       93
# 4  https://cdn.sofifa.org/flags/7.png   91       92
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# ID                          0
# Name                        0
# Age                         0
# Photo                       0
# Nationality                 0
# Flag                        0
# Overall                     0
# Potential                   0
# Club                        241
# Club Logo                   0
# Value                       0
# Wage                        0
# Special                     0
# Preferred Foot              48
# International Reputation    48
# Weak Foot                   48
# Skill Moves                 48
# Work Rate                   48
# Body Type                   48
# Real Face                   48
# Position                    60
# Jersey Number               60
# Joined                      1553
# Loaned From                 16943
# Contract Valid Until        289
# Height                      48
# Weight                      48
# LS                          2085
# ST                          2085
# ...

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

#df = df.drop(['Unnamed: 0'], axis=1)
#df.head()

# %% [markdown]
# drop colom yang tidak digunakan, tapi dari data diatas tidak perlu di drop semua karena akan mempengaruhi data analysis yang akan dibuat

# %%
df.drop(['Unnamed: 0','Photo','Flag','Club Logo','Loaned From'],axis=1,inplace=True)
df.head(2)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023  L. Messi           31   Argentina   94       94
# 1  20801   Cristiano Ronaldo  33   Portugal    94       94
#
#            Club    Value   Wage  Special Preferred Foot  \
# 0  FC Barcelona  €110.5M  €565K  2202     Left
# 1  Juventus      €77M     €405K  2228     Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0  5.0                       4.0        4.0          Medium/ Medium
# 1  5.0                       4.0        5.0          High/ Low
#
#     Body Type Real Face Position  Jersey Number        Joined  \
# 0  Messi       Yes       RF       10.0           Jul 1, 2004
# 1  C. Ronaldo  Yes       ST       7.0            Jul 10, 2018
#
#   Contract Valid Until Height  Weight    LS    ST    RS    LW    LF    CF  \
# 0  2021                 5'7    159lbs  88+2  88+2  88+2  92+2  93+2  93+2
# 1  2022                 6'2    183lbs  91+3  91+3  91+3  89+3  90+3  90+3
#
# ...

# %% [markdown]
# # Plotting dan Data analysis#

# %%
plt.rcParams['patch.force_edgecolor'] = True
sns.distplot(df['Age'].dropna(),kde=False,color='darkred',bins=30)
print("mean umur dari dataset diatas = ", df['Age'].mean())
# Out:
# mean umur dari dataset diatas =  25.122205745043114

# %% [markdown]
# penjelasan :sebaran data umur dari data set tsb , paling banyak di sekitar umur 20 awal  . dengan mean di 25,1 . mulai keliatan turun di umur 27an

# %%
plt.rcParams['patch.force_edgecolor'] = True
sns.jointplot(x=df['Age'],y=df['Potential'],alpha=0.1)

# %% [markdown]
# penjelasan : pemain bola , potensi mulai keliatan di umur 17an makin meningkat hingga berkurang di 28an tahun

# %%
sns.lmplot(data = df, x = 'Age', y = 'SprintSpeed',lowess=True,scatter_kws={'alpha':0.1, 's':5,'color':'green'}, 
           line_kws={'color':'red'})
#makin tua makin lambat

# %% [markdown]
# penjelasan : speed mulai berkurang di umur 28an
#
# penjelasan akhir : atritbut dari pemain mulai berkurang di umur 28an

# %%
#bagusan mana kaki kiri atau kanan?
plt.rcParams['patch.force_edgecolor'] = True
sns.lmplot(x = 'BallControl', y = 'Dribbling', data = df,col = 'Preferred Foot',scatter_kws = {'alpha':0.1,'color':'green'},
           line_kws={'color':'red'})

# %%
sns.violinplot(x="Preferred Foot", y="Overall", data=df,palette='rainbow')

# %%
df[['Value','Wage']].head()
# Out:
#      Value   Wage
# 0  €110.5M  €565K
# 1  €77M     €405K
# 2  €118.5M  €290K
# 3  €72M     €260K
# 4  €102M    €355K

# %% [markdown]
# Melakukan konversi kolom value dan wage

# %%
def konversi(a):
    try:
        value = float(a[1:-1])
        suffix = a[-1:]

        if suffix == 'M':
            value = value * 1000000
        elif suffix == 'K':
            value = value * 1000
    except ValueError:
        value = 0
    return value

# %%
df['Value'] = df['Value'].apply(konversi)
df['Wage'] = df['Wage'].apply(konversi)


df.Wage.mean()
# Out:
# 9731.312132696215

# %%
#dengan cara diatas
fitur = ['Value','Wage']

i=0
while i < len(fitur):
    print('Best {0} : {1}'.format(fitur[i],df.loc[df[fitur[i]].astype('float64').idxmax()][1]))
    i += 1
# Out:
# Best Value : Neymar Jr
# Best Wage : L. Messi

# %% [markdown]
# penjelasan : Neymar paling mahal harganya, Messi dibayar paling mahal

# %%
sns.jointplot(x=df['Wage'],y=df['Overall'],alpha=0.4,color='purple' )

# %%
#sns.swarmplot(x="Preferred Foot", y="Overall",data=df, palette="Set1", split=True)

# %%
print(df['Nationality'].value_counts().head(5))
df['Nationality'].nunique()
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina    937
# France       914
# Name: Nationality, dtype: int64
# 164

# %% [markdown]
# Mencari fitur - fitur maksimum pada tiap player

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW',
#        'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM',
#        'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
# ...

# %%
#skip dulu kebawah
df.loc[df.Finishing.idxmax()].head()

#fitur idxmax harus bertype float
# Out:
# ID             158023
# Name           L. Messi
# Age            31
# Nationality    Argentina
# Overall        94
# Name: 0, dtype: object

# %%
fitur= ['Crossing','Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling','Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration','SprintSpeed','Agility','Reactions','Balance','ShotPower','Jumping','Stamina','Strength','LongShots','Aggression','Interceptions','Positioning','Vision','Penalties','Composure','Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling','GKKicking', 'GKPositioning', 'GKReflexes']
#i=0
#while i < len(fiturmax):
    #print(fiturmax[i],df.loc[df[fiturmax[i]].idxmax()][1])
    #i += 1           
    
i=0
while i < len(fitur):
    print('Terbaik dalam {0} : {1}'.format(fitur[i],df.loc[df[fitur[i]].astype('float64').idxmax()][1]))
    i += 1
# Out:
# Terbaik dalam Crossing : K. De Bruyne
# Terbaik dalam Finishing : L. Messi
# Terbaik dalam HeadingAccuracy : Naldo
# Terbaik dalam ShortPassing : L. Modrić
# Terbaik dalam Volleys : E. Cavani
# Terbaik dalam Dribbling : L. Messi
# Terbaik dalam Curve : Quaresma
# Terbaik dalam FKAccuracy : L. Messi
# Terbaik dalam LongPassing : T. Kroos
# Terbaik dalam BallControl : L. Messi
# Terbaik dalam Acceleration : Douglas Costa
# Terbaik dalam SprintSpeed : K. Mbappé
# Terbaik dalam Agility : Neymar Jr
# Terbaik dalam Reactions : Cristiano Ronaldo
# Terbaik dalam Balance : Bernard
# Terbaik dalam ShotPower : Cristiano Ronaldo
# Terbaik dalam Jumping : Cristiano Ronaldo
# Terbaik dalam Stamina : N. Kanté
# Terbaik dalam Strength : A. Akinfenwa
# Terbaik dalam LongShots : L. Messi
# Terbaik dalam Aggression : B. Pearson
# Terbaik dalam Interceptions : N. Kanté
# Terbaik dalam Positioning : Cristiano Ronaldo
# Terbaik dalam Vision : L. Messi
# Terbaik dalam Penalties : M. Balotelli
# ...

# %% [markdown]
# analisis yang akan dilakukan :
#
# 3. extraksi fitur-fitur ( attack, defense) tiap liga
# 6. berapa standard pemain di top 3 tiap liga (posisi CF, MF dan CB)
# 7. melakukan clustering terhadap no. punggung using K means , melakukan clustering terhadap asal Nationality
# 9. analisis potensi terhadap gaji dulu, dibandingkan dengan gaji rata2 tiap club. kemana dia akan pindah bikin fitur untuk logistic regression
