# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('data.csv')
df.columns[28:54]
df = df.drop(['Unnamed: 0','ID','Photo','Flag','Club Logo','Joined','Special','Loaned From','Body Type', 'Release Clause',
               'Weight','Height','Contract Valid Until','Wage','Value'], axis = 1)
df = df.dropna()

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  L. Messi           31   Argentina   94       94
# 1  Cristiano Ronaldo  33   Portugal    94       94
# 2  Neymar Jr          26   Brazil      92       93
# 4  K. De Bruyne       27   Belgium     91       92
# 5  E. Hazard          27   Belgium     91       91
#
#                   Club Preferred Foot  International Reputation  Weak Foot  \
# 0  FC Barcelona         Left           5.0                       4.0
# 1  Juventus             Right          5.0                       4.0
# 2  Paris Saint-Germain  Right          5.0                       5.0
# 4  Manchester City      Right          4.0                       5.0
# 5  Chelsea              Right          4.0                       4.0
#
#    Skill Moves       Work Rate Real Face Position  Jersey Number    LS    ST  \
# 0  4.0          Medium/ Medium  Yes       RF       10.0           88+2  88+2
# 1  5.0          High/ Low       Yes       ST       7.0            91+3  91+3
# 2  5.0          High/ Medium    Yes       LW       10.0           84+3  84+3
# 4  4.0          High/ High      Yes       RCM      7.0            82+3  82+3
# 5  4.0          High/ Medium    Yes       LF       10.0           83+3  83+3
#
#      RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 0  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2  93+2  91+2  84+2  84+2
# 1  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3
# 2  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  88+3  81+3  81+3
# 4  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3
# 5  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  82+3  82+3
#
#     RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 0  84+2  91+2  64+2  61+2  61+2  61+2  64+2  59+2  47+2  47+2  47+2  59+2
# 1  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  81+3  88+3  65+3  60+3  60+3  60+3  65+3  60+3  47+3  47+3  47+3  60+3
# 4  87+3  88+3  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
# 5  82+3  89+3  66+3  63+3  63+3  63+3  66+3  60+3  49+3  49+3  49+3  60+3
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0  84.0      95.0       70.0             90.0          86.0     97.0
# 1  84.0      94.0       89.0             81.0          87.0     88.0
# 2  79.0      87.0       62.0             84.0          84.0     96.0
# 4  93.0      82.0       55.0             92.0          82.0     86.0
# 5  81.0      84.0       61.0             89.0          80.0     95.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 0  93.0   94.0        87.0         96.0         91.0          86.0
# 1  81.0   76.0        77.0         94.0         89.0          91.0
# 2  88.0   87.0        78.0         95.0         94.0          90.0
# 4  85.0   83.0        91.0         91.0         78.0          76.0
# 5  83.0   79.0        83.0         94.0         94.0          88.0
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0  91.0     95.0       95.0     85.0       68.0     72.0     59.0
# 1  87.0     96.0       70.0     95.0       95.0     88.0     79.0
# 2  96.0     94.0       84.0     80.0       61.0     81.0     49.0
# 4  79.0     91.0       77.0     91.0       63.0     90.0     75.0
# 5  95.0     90.0       94.0     82.0       56.0     83.0     66.0
#
#    LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0  94.0       48.0        22.0           94.0         94.0    75.0
# 1  93.0       63.0        29.0           95.0         82.0    85.0
# 2  82.0       56.0        36.0           89.0         87.0    81.0
# 4  91.0       76.0        61.0           87.0         94.0    79.0
# 5  80.0       54.0        41.0           87.0         89.0    86.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0  96.0       33.0     28.0            26.0           6.0       11.0
# 1  95.0       28.0     31.0            23.0           7.0       11.0
# 2  94.0       27.0     24.0            33.0           9.0       9.0
# 4  88.0       68.0     58.0            51.0           15.0      13.0
# 5  91.0       34.0     27.0            22.0           11.0      12.0
#
#    GKKicking  GKPositioning  GKReflexes
# 0  15.0       14.0           8.0
# 1  15.0       14.0           11.0
# 2  15.0       15.0           11.0
# 4  5.0        10.0           13.0
# 5  6.0        8.0            8.0

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3)

# %%
#sumsquare error & elbow method

ssr=[]
for x in range(1,11):
    model = KMeans(n_clusters=x)
    model.fit(df[['Jersey Number','Overall']])
    ssr.append(model.inertia_)

# %%
#elbow method
plt.plot(
        np.arange(1,11),
        ssr,'b-')
plt.xlabel('range')
plt.ylabel('sumsquare error')
plt.grid(True)

# %%
model.cluster_centers_
# Out:
# array([[20.05532213, 75.47408964],
#        [43.62589928, 63.50359712],
#        [ 6.28651336, 64.39776259],
#        [31.55135135, 56.72355212],
#        [27.63714029, 67.20908273],
#        [16.07046293, 66.98893896],
#        [ 7.00704225, 74.38235294],
#        [19.17408907, 58.7593985 ],
#        [71.96052632, 65.10087719],
#        [93.11023622, 65.47637795]])

# %%
model.labels_
# Out:
# array([6, 6, 6, ..., 3, 3, 3])

# %%
#training
model.fit(df[['Jersey Number','Overall']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#predict

prediksi=model.predict(df[['Jersey Number','Overall']])

# %%
df['cluster'] = prediksi #labelnya
df[df.cluster == 7].head(20)
# Out:
#                   Name  Age       Nationality  Overall  Potential  \
# 5660  V. Fındıklı       27   Turkey            69       70
# 5685  C. Labrín         27   Chile             69       71
# 5739  A. Powell         23   Jamaica           69       74
# 5770  Gustavo Cascardo  21   Brazil            69       76
# 5849  I. Sackey         24   Ghana             69       76
# 5854  N. Byrne          26   England           69       72
# 5902  E. Velarde        32   Mexico            69       69
# 5924  Luis Pérez        23   Spain             69       77
# 5992  I. Jiménez        28   Mexico            69       69
# 5999  E. Castillo       31   United States     69       69
# 6009  L. Peltier        31   England           69       69
# 6043  A. Farrell        26   United States     69       70
# 6105  M. Zeffane        26   Algeria           69       70
# 6186  B. Beckeles       32   Honduras          69       69
# 6196  C. McLaughlin     26   Northern Ireland  69       70
# 6205  D. De fauw        36   Belgium           69       69
# 6209  V. Hedenstad      27   Norway            69       70
# 6228  E. Pisano         31   Italy             69       69
# 6241  M. Diallo         32   Senegal           69       69
# 6283  L. Wahlqvist      21   Sweden            69       76
#
#                         Club Preferred Foot  International Reputation  \
# 5660  Atiker Konyaspor        Right          1.0
# 5685  Audax Italiano          Right          1.0
# 5739  Portland Timbers        Right          1.0
# 5770  Vitória de Setúbal      Right          1.0
# 5849  Alanyaspor              Right          1.0
# 5854  Wigan Athletic          Right          1.0
# 5902  Monarcas Morelia        Left           1.0
# 5924  CD Tenerife             Right          1.0
# 5992  Tigres U.A.N.L.         Right          1.0
# 5999  Colorado Rapids         Left           1.0
# 6009  Cardiff City            Right          1.0
# 6043  New England Revolution  Right          1.0
# 6105  Stade Rennais FC        Right          1.0
# 6186  Club Necaxa             Right          1.0
# 6196  Millwall                Right          1.0
# 6205  SV Zulte-Waregem        Right          1.0
# 6209  Rosenborg BK            Right          1.0
# 6228  Bristol City            Right          1.0
# 6241  Nîmes Olympique         Right          1.0
# 6283  SG Dynamo Dresden       Right          1.0
#
#       Weak Foot  Skill Moves       Work Rate Real Face Position  \
# 5660  2.0        2.0          Medium/ High    No        CDM
# 5685  2.0        2.0          Low/ High       No        RCB
# 5739  3.0        3.0          High/ Medium    Yes       RB
# 5770  3.0        3.0          High/ Medium    No        RB
# 5849  2.0        2.0          Medium/ High    No        RDM
# 5854  3.0        3.0          High/ Medium    No        RM
# 5902  2.0        2.0          Medium/ Medium  No        LB
# 5924  2.0        3.0          High/ Medium    No        RB
# 5992  3.0        3.0          High/ Medium    No        RB
# 5999  3.0        3.0          High/ Medium    No        LB
# 6009  2.0        2.0          Low/ High       No        RB
# 6043  2.0        3.0          Medium/ Medium  No        RB
# 6105  3.0        3.0          Medium/ High    No        LB
# 6186  3.0        2.0          Medium/ High    No        RB
# 6196  3.0        3.0          High/ Medium    No        RB
# 6205  4.0        2.0          High/ High      No        RB
# 6209  3.0        3.0          High/ Medium    No        RB
# 6228  3.0        3.0          High/ Medium    No        RB
# 6241  3.0        2.0          Medium/ High    No        CDM
# 6283  2.0        2.0          Medium/ High    No        RWB
#
#       Jersey Number    LS    ST    RS    LW    LF    CF    RF    RW   LAM  \
# 5660  2.0            52+2  52+2  52+2  53+2  54+2  54+2  54+2  53+2  56+2
# 5685  2.0            44+2  44+2  44+2  40+2  41+2  41+2  41+2  40+2  41+2
# 5739  2.0            59+2  59+2  59+2  63+2  61+2  61+2  61+2  63+2  61+2
# 5770  2.0            56+2  56+2  56+2  63+2  60+2  60+2  60+2  63+2  61+2
# 5849  2.0            59+2  59+2  59+2  54+2  56+2  56+2  56+2  54+2  56+2
# 5854  2.0            59+2  59+2  59+2  65+2  62+2  62+2  62+2  65+2  62+2
# 5902  2.0            61+2  61+2  61+2  63+2  62+2  62+2  62+2  63+2  63+2
# 5924  2.0            56+2  56+2  56+2  62+2  59+2  59+2  59+2  62+2  60+2
# 5992  2.0            61+2  61+2  61+2  64+2  64+2  64+2  64+2  64+2  65+2
# 5999  2.0            64+2  64+2  64+2  68+2  67+2  67+2  67+2  68+2  68+2
# 6009  2.0            53+2  53+2  53+2  57+2  56+2  56+2  56+2  57+2  57+2
# 6043  2.0            58+2  58+2  58+2  61+2  60+2  60+2  60+2  61+2  60+2
# 6105  2.0            63+2  63+2  63+2  65+2  64+2  64+2  64+2  65+2  64+2
# 6186  2.0            58+2  58+2  58+2  58+2  58+2  58+2  58+2  58+2  58+2
# 6196  2.0            59+2  59+2  59+2  62+2  60+2  60+2  60+2  62+2  61+2
# 6205  2.0            58+2  58+2  58+2  59+2  60+2  60+2  60+2  59+2  62+2
# 6209  2.0            61+2  61+2  61+2  65+2  63+2  63+2  63+2  65+2  63+2
# 6228  2.0            58+2  58+2  58+2  59+2  58+2  58+2  58+2  59+2  57+2
# 6241  2.0            58+2  58+2  58+2  55+2  57+2  57+2  57+2  55+2  58+2
# 6283  2.0            55+2  55+2  55+2  58+2  56+2  56+2  56+2  58+2  57+2
#
#        CAM   RAM    LM   LCM    CM   RCM    RM   LWB   LDM   CDM   RDM   RWB  \
# 5660  56+2  56+2  56+2  62+2  62+2  62+2  56+2  62+2  67+2  67+2  67+2  62+2
# 5685  41+2  41+2  42+2  45+2  45+2  45+2  42+2  56+2  58+2  58+2  58+2  56+2
# 5739  61+2  61+2  64+2  60+2  60+2  60+2  64+2  67+2  64+2  64+2  64+2  67+2
# 5770  61+2  61+2  65+2  62+2  62+2  62+2  65+2  68+2  64+2  64+2  64+2  68+2
# 5849  56+2  56+2  55+2  61+2  61+2  61+2  55+2  62+2  67+2  67+2  67+2  62+2
# 5854  62+2  62+2  66+2  62+2  62+2  62+2  66+2  68+2  64+2  64+2  64+2  68+2
# 5902  63+2  63+2  64+2  64+2  64+2  64+2  64+2  67+2  66+2  66+2  66+2  67+2
# 5924  60+2  60+2  63+2  59+2  59+2  59+2  63+2  68+2  63+2  63+2  63+2  68+2
# 5992  65+2  65+2  66+2  67+2  67+2  67+2  66+2  68+2  68+2  68+2  68+2  68+2
# 5999  68+2  68+2  69+2  66+2  66+2  66+2  69+2  69+2  66+2  66+2  66+2  69+2
# 6009  57+2  57+2  59+2  60+2  60+2  60+2  59+2  67+2  67+2  67+2  67+2  67+2
# 6043  60+2  60+2  63+2  62+2  62+2  62+2  63+2  68+2  66+2  66+2  66+2  68+2
# 6105  64+2  64+2  66+2  66+2  66+2  66+2  66+2  69+2  67+2  67+2  67+2  69+2
# 6186  58+2  58+2  60+2  62+2  62+2  62+2  60+2  67+2  67+2  67+2  67+2  67+2
# 6196  61+2  61+2  64+2  63+2  63+2  63+2  64+2  68+2  66+2  66+2  66+2  68+2
# 6205  62+2  62+2  62+2  67+2  67+2  67+2  62+2  68+2  70+2  70+2  70+2  68+2
# 6209  63+2  63+2  66+2  64+2  64+2  64+2  66+2  68+2  65+2  65+2  65+2  68+2
# 6228  57+2  57+2  61+2  60+2  60+2  60+2  61+2  67+2  66+2  66+2  66+2  67+2
# 6241  58+2  58+2  57+2  63+2  63+2  63+2  57+2  62+2  68+2  68+2  68+2  62+2
# 6283  57+2  57+2  60+2  60+2  60+2  60+2  60+2  67+2  65+2  65+2  65+2  67+2
#
#         LB   LCB    CB   RCB    RB  Crossing  Finishing  HeadingAccuracy  \
# 5660  61+2  67+2  67+2  67+2  61+2  52.0      34.0       60.0
# 5685  59+2  67+2  67+2  67+2  59+2  31.0      22.0       67.0
# 5739  68+2  67+2  67+2  67+2  68+2  59.0      37.0       59.0
# 5770  68+2  62+2  62+2  62+2  68+2  70.0      33.0       54.0
# 5849  63+2  71+2  71+2  71+2  63+2  44.0      48.0       77.0
# 5854  67+2  63+2  63+2  63+2  67+2  69.0      50.0       56.0
# 5902  67+2  66+2  66+2  66+2  67+2  70.0      52.0       57.0
# 5924  68+2  64+2  64+2  64+2  68+2  62.0      42.0       54.0
# 5992  67+2  67+2  67+2  67+2  67+2  67.0      45.0       58.0
# 5999  68+2  65+2  65+2  65+2  68+2  66.0      52.0       51.0
# 6009  67+2  70+2  70+2  70+2  67+2  60.0      40.0       63.0
# 6043  67+2  67+2  67+2  67+2  67+2  59.0      41.0       49.0
# 6105  68+2  64+2  64+2  64+2  68+2  70.0      55.0       57.0
# 6186  68+2  69+2  69+2  69+2  68+2  62.0      46.0       63.0
# 6196  68+2  67+2  67+2  67+2  68+2  71.0      43.0       62.0
# 6205  68+2  69+2  69+2  69+2  68+2  76.0      39.0       78.0
# 6209  68+2  63+2  63+2  63+2  68+2  68.0      46.0       52.0
# 6228  68+2  70+2  70+2  70+2  68+2  68.0      27.0       73.0
# 6241  62+2  70+2  70+2  70+2  62+2  59.0      48.0       77.0
# 6283  67+2  67+2  67+2  67+2  67+2  67.0      29.0       62.0
#
#       ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 5660  74.0          31.0     70.0       37.0   39.0        65.0
# 5685  48.0          26.0     38.0       36.0   28.0        36.0
# 5739  54.0          29.0     72.0       48.0   29.0        55.0
# 5770  65.0          27.0     67.0       57.0   38.0        60.0
# 5849  64.0          32.0     60.0       41.0   46.0        60.0
# 5854  68.0          41.0     67.0       49.0   33.0        63.0
# 5902  66.0          61.0     60.0       60.0   60.0        64.0
# 5924  60.0          29.0     67.0       53.0   45.0        46.0
# 5992  68.0          43.0     67.0       65.0   58.0        64.0
# 5999  68.0          53.0     72.0       65.0   60.0        59.0
# 6009  62.0          28.0     60.0       49.0   38.0        55.0
# 6043  62.0          52.0     65.0       55.0   53.0        59.0
# 6105  69.0          57.0     62.0       58.0   47.0        64.0
# 6186  67.0          40.0     50.0       40.0   34.0        57.0
# 6196  66.0          35.0     64.0       61.0   44.0        60.0
# 6205  70.0          29.0     59.0       64.0   70.0        71.0
# 6209  67.0          46.0     68.0       69.0   71.0        57.0
# 6228  65.0          47.0     65.0       63.0   40.0        61.0
# 6241  73.0          46.0     57.0       50.0   46.0        66.0
# 6283  60.0          38.0     56.0       66.0   31.0        55.0
#
#       BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 5660  72.0         34.0          37.0         42.0     57.0       60.0
# 5685  48.0         55.0          55.0         53.0     64.0       49.0
# 5739  64.0         82.0          91.0         84.0     64.0       72.0
# 5770  69.0         82.0          83.0         79.0     64.0       83.0
# 5849  65.0         55.0          43.0         57.0     52.0       42.0
# 5854  66.0         90.0          83.0         75.0     63.0       77.0
# 5902  65.0         68.0          71.0         71.0     69.0       72.0
# 5924  65.0         86.0          89.0         83.0     66.0       77.0
# 5992  69.0         68.0          62.0         70.0     68.0       73.0
# 5999  67.0         82.0          79.0         86.0     71.0       74.0
# 6009  63.0         65.0          57.0         53.0     65.0       70.0
# 6043  65.0         79.0          77.0         74.0     66.0       71.0
# 6105  66.0         69.0          77.0         74.0     66.0       79.0
# 6186  62.0         63.0          65.0         56.0     64.0       42.0
# 6196  66.0         74.0          67.0         71.0     63.0       63.0
# 6205  68.0         42.0          43.0         60.0     66.0       62.0
# 6209  69.0         78.0          74.0         79.0     69.0       75.0
# 6228  64.0         66.0          69.0         71.0     69.0       62.0
# 6241  67.0         34.0          39.0         35.0     70.0       41.0
# 6283  66.0         74.0          72.0         65.0     68.0       56.0
#
#       ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 5660  65.0       67.0     62.0     82.0      36.0       75.0
# 5685  48.0       75.0     59.0     81.0      37.0       75.0
# 5739  62.0       80.0     79.0     71.0      48.0       80.0
# 5770  66.0       68.0     79.0     50.0      52.0       62.0
# 5849  79.0       68.0     76.0     90.0      78.0       72.0
# 5854  56.0       66.0     78.0     62.0      55.0       62.0
# 5902  66.0       73.0     70.0     72.0      61.0       65.0
# 5924  51.0       76.0     78.0     63.0      45.0       64.0
# 5992  60.0       70.0     70.0     68.0      59.0       69.0
# 5999  69.0       89.0     77.0     66.0      62.0       70.0
# 6009  32.0       83.0     72.0     66.0      39.0       80.0
# 6043  61.0       67.0     82.0     77.0      51.0       75.0
# 6105  78.0       71.0     90.0     62.0      63.0       71.0
# 6186  65.0       83.0     90.0     82.0      54.0       73.0
# 6196  62.0       87.0     81.0     67.0      43.0       65.0
# 6205  72.0       46.0     77.0     62.0      68.0       68.0
# 6209  75.0       57.0     83.0     59.0      53.0       67.0
# 6228  66.0       75.0     68.0     79.0      50.0       71.0
# 6241  60.0       75.0     61.0     80.0      60.0       88.0
# 6283  72.0       80.0     78.0     65.0      62.0       72.0
#
#       Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 5660  70.0           37.0         51.0    56.0       49.0       68.0
# 5685  65.0           25.0         32.0    41.0       66.0       68.0
# 5739  67.0           63.0         57.0    36.0       60.0       63.0
# 5770  65.0           54.0         52.0    48.0       62.0       59.0
# 5849  74.0           38.0         52.0    52.0       52.0       70.0
# 5854  60.0           50.0         52.0    42.0       55.0       66.0
# 5902  66.0           56.0         64.0    63.0       63.0       68.0
# 5924  68.0           48.0         53.0    44.0       65.0       65.0
# 5992  69.0           68.0         69.0    61.0       70.0       65.0
# 5999  66.0           69.0         66.0    64.0       59.0       66.0
# 6009  73.0           56.0         57.0    38.0       63.0       72.0
# 6043  66.0           59.0         52.0    31.0       60.0       68.0
# 6105  68.0           59.0         62.0    60.0       61.0       63.0
# 6186  67.0           55.0         61.0    43.0       65.0       60.0
# 6196  65.0           60.0         61.0    49.0       65.0       67.0
# 6205  75.0           58.0         68.0    78.0       80.0       78.0
# 6209  59.0           58.0         58.0    45.0       65.0       63.0
# 6228  69.0           59.0         39.0    55.0       69.0       70.0
# 6241  65.0           50.0         54.0    48.0       62.0       66.0
# 6283  69.0           43.0         54.0    30.0       65.0       67.0
#
#       StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 5660  66.0            64.0           10.0      8.0         8.0
# 5685  72.0            68.0           15.0      15.0        15.0
# 5739  71.0            69.0           8.0       7.0         11.0
# 5770  65.0            68.0           8.0       10.0        11.0
# 5849  72.0            68.0           14.0      10.0        8.0
# 5854  65.0            63.0           8.0       8.0         7.0
# 5902  68.0            68.0           9.0       8.0         13.0
# 5924  66.0            65.0           9.0       10.0        6.0
# 5992  70.0            70.0           15.0      14.0        11.0
# 5999  65.0            65.0           14.0      8.0         6.0
# 6009  74.0            73.0           6.0       7.0         13.0
# 6043  70.0            68.0           15.0      16.0        12.0
# 6105  62.0            65.0           15.0      12.0        9.0
# 6186  75.0            73.0           10.0      15.0        12.0
# 6196  72.0            66.0           9.0       13.0        8.0
# 6205  68.0            67.0           8.0       11.0        14.0
# 6209  69.0            67.0           12.0      16.0        7.0
# 6228  68.0            71.0           12.0      7.0         15.0
# 6241  67.0            65.0           8.0       12.0        7.0
# 6283  69.0            64.0           12.0      6.0         12.0
#
#       GKPositioning  GKReflexes  cluster
# 5660  8.0            7.0         7
# 5685  10.0           12.0        7
# 5739  8.0            10.0        7
# 5770  9.0            6.0         7
# 5849  12.0           7.0         7
# 5854  10.0           11.0        7
# 5902  10.0           10.0        7
# 5924  7.0            13.0        7
# 5992  12.0           9.0         7
# 5999  13.0           10.0        7
# 6009  10.0           15.0        7
# 6043  10.0           15.0        7
# 6105  13.0           10.0        7
# 6186  9.0            14.0        7
# 6196  8.0            6.0         7
# 6205  15.0           15.0        7
# 6209  7.0            7.0         7
# 6228  7.0            13.0        7
# 6241  13.0           16.0        7
# 6283  9.0            9.0         7

# %%
df.cluster.nunique()
# Out:
# 10

# %%
df['cluster'] = prediksi
df[df.cluster == 2].head()
# Out:
#              Name  Age     Nationality  Overall  Potential      Club  \
# 208   Giuliano     28   Brazil          83       83         Al Nassr
# 333   M. Brozović  25   Croatia         81       84         Inter
# 759   A. Marušić   25   Montenegro      78       79         Lazio
# 1070  P. Cutrone   20   Italy           77       89         Milan
# 1183  A. Barák     23   Czech Republic  77       84         Udinese
#
#      Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 208   Right          2.0                       3.0        4.0
# 333   Right          2.0                       4.0        3.0
# 759   Right          1.0                       4.0        4.0
# 1070  Right          1.0                       3.0        3.0
# 1183  Left           1.0                       3.0        4.0
#
#            Work Rate Real Face Position  Jersey Number    LS    ST    RS  \
# 208   High/ Medium    No        CAM      77.0           77+2  77+2  77+2
# 333   Medium/ Medium  Yes       LDM      77.0           73+2  73+2  73+2
# 759   High/ Medium    No        RM       77.0           75+2  75+2  75+2
# 1070  High/ Medium    No        RS       63.0           75+2  75+2  75+2
# 1183  High/ Medium    No        CM       72.0           72+2  72+2  72+2
#
#         LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM   RCM  \
# 208   81+2  80+2  80+2  80+2  81+2  81+2  81+2  81+2  81+2  77+2  77+2  77+2
# 333   76+2  76+2  76+2  76+2  76+2  78+2  78+2  78+2  77+2  80+2  80+2  80+2
# 759   76+2  75+2  75+2  75+2  76+2  74+2  74+2  74+2  76+2  73+2  73+2  73+2
# 1070  71+2  73+2  73+2  73+2  71+2  69+2  69+2  69+2  68+2  60+2  60+2  60+2
# 1183  74+2  74+2  74+2  74+2  74+2  75+2  75+2  75+2  74+2  76+2  76+2  76+2
#
#         RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 208   81+2  66+2  65+2  65+2  65+2  66+2  62+2  56+2  56+2  56+2  62+2
# 333   77+2  77+2  79+2  79+2  79+2  77+2  76+2  74+2  74+2  74+2  76+2
# 759   76+2  76+2  73+2  73+2  73+2  76+2  75+2  73+2  73+2  73+2  75+2
# 1070  68+2  50+2  47+2  47+2  47+2  50+2  47+2  45+2  45+2  45+2  47+2
# 1183  74+2  67+2  67+2  67+2  67+2  67+2  65+2  61+2  61+2  61+2  65+2
#
#       Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 208   77.0      79.0       59.0             82.0          65.0     84.0
# 333   72.0      69.0       62.0             83.0          65.0     81.0
# 759   78.0      66.0       72.0             75.0          68.0     78.0
# 1070  48.0      80.0       76.0             70.0          72.0     74.0
# 1183  72.0      68.0       60.0             80.0          64.0     78.0
#
#       Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 208   67.0   71.0        79.0         84.0         85.0          79.0
# 333   79.0   74.0        83.0         83.0         69.0          70.0
# 759   72.0   48.0        68.0         77.0         86.0          89.0
# 1070  68.0   42.0        34.0         76.0         75.0          77.0
# 1183  62.0   66.0        78.0         80.0         66.0          68.0
#
#       Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 208   85.0     81.0       85.0     78.0       61.0     82.0     74.0
# 333   74.0     77.0       74.0     80.0       68.0     84.0     66.0
# 759   66.0     76.0       67.0     81.0       80.0     79.0     79.0
# 1070  69.0     74.0       76.0     74.0       75.0     72.0     74.0
# 1183  63.0     72.0       63.0     81.0       58.0     77.0     78.0
#
#       LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 208   76.0       71.0        42.0           81.0         80.0    79.0
# 333   81.0       79.0        81.0           69.0         80.0    69.0
# 759   77.0       71.0        73.0           73.0         72.0    58.0
# 1070  62.0       60.0        14.0           80.0         56.0    68.0
# 1183  78.0       58.0        64.0           74.0         76.0    66.0
#
#       Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 208   82.0       49.0     43.0            38.0           16.0      11.0
# 333   78.0       75.0     77.0            75.0           8.0       8.0
# 759   72.0       72.0     71.0            72.0           8.0       9.0
# 1070  72.0       36.0     20.0            18.0           10.0      7.0
# 1183  76.0       25.0     66.0            62.0           14.0      15.0
#
#       GKKicking  GKPositioning  GKReflexes  cluster
# 208   13.0       9.0            8.0         2
# 333   15.0       11.0           8.0         2
# 759   7.0        10.0           10.0        2
# 1070  7.0        10.0           5.0         2
# 1183  10.0       12.0           11.0        2

# %%
df['cluster'] = prediksi
df[df.cluster == 1].head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  L. Messi           31   Argentina   94       94
# 1  Cristiano Ronaldo  33   Portugal    94       94
# 2  Neymar Jr          26   Brazil      92       93
# 4  K. De Bruyne       27   Belgium     91       92
# 5  E. Hazard          27   Belgium     91       91
#
#                   Club Preferred Foot  International Reputation  Weak Foot  \
# 0  FC Barcelona         Left           5.0                       4.0
# 1  Juventus             Right          5.0                       4.0
# 2  Paris Saint-Germain  Right          5.0                       5.0
# 4  Manchester City      Right          4.0                       5.0
# 5  Chelsea              Right          4.0                       4.0
#
#    Skill Moves       Work Rate Real Face Position  Jersey Number    LS    ST  \
# 0  4.0          Medium/ Medium  Yes       RF       10.0           88+2  88+2
# 1  5.0          High/ Low       Yes       ST       7.0            91+3  91+3
# 2  5.0          High/ Medium    Yes       LW       10.0           84+3  84+3
# 4  4.0          High/ High      Yes       RCM      7.0            82+3  82+3
# 5  4.0          High/ Medium    Yes       LF       10.0           83+3  83+3
#
#      RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 0  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2  93+2  91+2  84+2  84+2
# 1  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3
# 2  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  88+3  81+3  81+3
# 4  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3
# 5  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  82+3  82+3
#
#     RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 0  84+2  91+2  64+2  61+2  61+2  61+2  64+2  59+2  47+2  47+2  47+2  59+2
# 1  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  81+3  88+3  65+3  60+3  60+3  60+3  65+3  60+3  47+3  47+3  47+3  60+3
# 4  87+3  88+3  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
# 5  82+3  89+3  66+3  63+3  63+3  63+3  66+3  60+3  49+3  49+3  49+3  60+3
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0  84.0      95.0       70.0             90.0          86.0     97.0
# 1  84.0      94.0       89.0             81.0          87.0     88.0
# 2  79.0      87.0       62.0             84.0          84.0     96.0
# 4  93.0      82.0       55.0             92.0          82.0     86.0
# 5  81.0      84.0       61.0             89.0          80.0     95.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 0  93.0   94.0        87.0         96.0         91.0          86.0
# 1  81.0   76.0        77.0         94.0         89.0          91.0
# 2  88.0   87.0        78.0         95.0         94.0          90.0
# 4  85.0   83.0        91.0         91.0         78.0          76.0
# 5  83.0   79.0        83.0         94.0         94.0          88.0
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0  91.0     95.0       95.0     85.0       68.0     72.0     59.0
# 1  87.0     96.0       70.0     95.0       95.0     88.0     79.0
# 2  96.0     94.0       84.0     80.0       61.0     81.0     49.0
# 4  79.0     91.0       77.0     91.0       63.0     90.0     75.0
# 5  95.0     90.0       94.0     82.0       56.0     83.0     66.0
#
#    LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0  94.0       48.0        22.0           94.0         94.0    75.0
# 1  93.0       63.0        29.0           95.0         82.0    85.0
# 2  82.0       56.0        36.0           89.0         87.0    81.0
# 4  91.0       76.0        61.0           87.0         94.0    79.0
# 5  80.0       54.0        41.0           87.0         89.0    86.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0  96.0       33.0     28.0            26.0           6.0       11.0
# 1  95.0       28.0     31.0            23.0           7.0       11.0
# 2  94.0       27.0     24.0            33.0           9.0       9.0
# 4  88.0       68.0     58.0            51.0           15.0      13.0
# 5  91.0       34.0     27.0            22.0           11.0      12.0
#
#    GKKicking  GKPositioning  GKReflexes  cluster
# 0  15.0       14.0           8.0         1
# 1  15.0       14.0           11.0        1
# 2  15.0       15.0           11.0        1
# 4  5.0        10.0           13.0        1
# 5  6.0        8.0            8.0         1

# %%
df['cluster'] = prediksi
df[df.cluster == 3].head()
# Out:
#             Name  Age Nationality  Overall  Potential                 Club  \
# 8   Sergio Ramos  32   Spain       91       91         Real Madrid
# 13  David Silva   32   Spain       90       90         Manchester City
# 14  N. Kanté      27   France      89       90         Chelsea
# 15  P. Dybala     24   Argentina   89       94         Juventus
# 21  E. Cavani     31   Uruguay     89       89         Paris Saint-Germain
#
#    Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 8   Right          4.0                       3.0        3.0
# 13  Left           4.0                       2.0        4.0
# 14  Right          3.0                       3.0        2.0
# 15  Left           3.0                       3.0        4.0
# 21  Right          4.0                       4.0        3.0
#
#        Work Rate Real Face Position  Jersey Number    LS    ST    RS    LW  \
# 8   High/ Medium  Yes       RCB      15.0           73+3  73+3  73+3  70+3
# 13  High/ Medium  Yes       LCM      21.0           77+3  77+3  77+3  85+3
# 14  Medium/ High  Yes       LDM      13.0           72+3  72+3  72+3  77+3
# 15  High/ Medium  Yes       LF       21.0           83+3  83+3  83+3  87+3
# 21  High/ High    Yes       LS       21.0           85+3  85+3  85+3  81+3
#
#       LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM   RCM    RM  \
# 8   71+3  71+3  71+3  70+3  71+3  71+3  71+3  72+3  75+3  75+3  75+3  72+3
# 13  84+3  84+3  84+3  85+3  87+3  87+3  87+3  85+3  85+3  85+3  85+3  85+3
# 14  77+3  77+3  77+3  77+3  79+3  79+3  79+3  79+3  82+3  82+3  82+3  79+3
# 15  86+3  86+3  86+3  87+3  87+3  87+3  87+3  86+3  79+3  79+3  79+3  86+3
# 21  83+3  83+3  83+3  81+3  80+3  80+3  80+3  79+3  75+3  75+3  75+3  79+3
#
#      LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  Crossing  \
# 8   81+3  84+3  84+3  84+3  81+3  84+3  87+3  87+3  87+3  84+3  66.0
# 13  69+3  70+3  70+3  70+3  69+3  64+3  57+3  57+3  57+3  64+3  84.0
# 14  85+3  87+3  87+3  87+3  85+3  84+3  83+3  83+3  83+3  84+3  68.0
# 15  62+3  58+3  58+3  58+3  62+3  56+3  45+3  45+3  45+3  56+3  82.0
# 21  67+3  65+3  65+3  65+3  67+3  65+3  63+3  63+3  63+3  65+3  70.0
#
#     Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  \
# 8   60.0       91.0             78.0          66.0     63.0       74.0
# 13  76.0       54.0             93.0          82.0     89.0       82.0
# 14  65.0       54.0             86.0          56.0     79.0       49.0
# 15  84.0       68.0             87.0          88.0     92.0       88.0
# 21  89.0       89.0             78.0          90.0     80.0       77.0
#
#     FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  Agility  \
# 8   72.0        77.0         84.0         76.0          75.0         78.0
# 13  77.0        87.0         94.0         70.0          64.0         92.0
# 14  49.0        81.0         80.0         82.0          78.0         82.0
# 15  88.0        75.0         92.0         87.0          83.0         91.0
# 21  76.0        52.0         82.0         75.0          76.0         77.0
#
#     Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  \
# 8   85.0       66.0     79.0       93.0     84.0     83.0      59.0
# 13  90.0       90.0     72.0       64.0     78.0     52.0      75.0
# 14  93.0       92.0     71.0       77.0     96.0     76.0      69.0
# 15  86.0       85.0     82.0       75.0     80.0     65.0      88.0
# 21  91.0       59.0     87.0       88.0     92.0     78.0      79.0
#
#     Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 8   88.0        90.0           60.0         63.0    75.0       82.0
# 13  57.0        50.0           89.0         92.0    75.0       93.0
# 14  90.0        92.0           71.0         79.0    54.0       85.0
# 15  48.0        32.0           84.0         87.0    86.0       84.0
# 21  84.0        48.0           93.0         77.0    85.0       82.0
#
#     Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 8   87.0     92.0            91.0           11.0      8.0         9.0
# 13  59.0     53.0            29.0           6.0       15.0        7.0
# 14  90.0     91.0            85.0           15.0      12.0        10.0
# 15  23.0     20.0            20.0           5.0       4.0         4.0
# 21  52.0     45.0            39.0           12.0      5.0         13.0
#
#     GKPositioning  GKReflexes  cluster
# 8   7.0            11.0        3
# 13  6.0            12.0        3
# 14  7.0            10.0        3
# 15  5.0            8.0         3
# 21  13.0           10.0        3

# %%
#seperate data prediksi
cluster1 = df[df['cluster'] == 1] 
cluster2 = df[df['cluster'] == 2] 
cluster3 = df[df['cluster'] == 3] 
cluster4 = df[df['cluster'] == 4] 
cluster5 = df[df['cluster'] == 5] 
cluster6 = df[df['cluster'] == 6] 
cluster7 = df[df['cluster'] == 7] 
cluster8 = df[df['cluster'] == 8] 
cluster9 = df[df['cluster'] == 9] 
cluster0 = df[df['cluster'] == 0]

# %%
cluster1.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  L. Messi           31   Argentina   94       94
# 1  Cristiano Ronaldo  33   Portugal    94       94
# 2  Neymar Jr          26   Brazil      92       93
# 4  K. De Bruyne       27   Belgium     91       92
# 5  E. Hazard          27   Belgium     91       91
#
#                   Club Preferred Foot  International Reputation  Weak Foot  \
# 0  FC Barcelona         Left           5.0                       4.0
# 1  Juventus             Right          5.0                       4.0
# 2  Paris Saint-Germain  Right          5.0                       5.0
# 4  Manchester City      Right          4.0                       5.0
# 5  Chelsea              Right          4.0                       4.0
#
#    Skill Moves       Work Rate Real Face Position  Jersey Number    LS    ST  \
# 0  4.0          Medium/ Medium  Yes       RF       10.0           88+2  88+2
# 1  5.0          High/ Low       Yes       ST       7.0            91+3  91+3
# 2  5.0          High/ Medium    Yes       LW       10.0           84+3  84+3
# 4  4.0          High/ High      Yes       RCM      7.0            82+3  82+3
# 5  4.0          High/ Medium    Yes       LF       10.0           83+3  83+3
#
#      RS    LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# 0  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2  93+2  91+2  84+2  84+2
# 1  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3
# 2  84+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  89+3  88+3  81+3  81+3
# 4  82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3
# 5  83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  82+3  82+3
#
#     RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB  \
# 0  84+2  91+2  64+2  61+2  61+2  61+2  64+2  59+2  47+2  47+2  47+2  59+2
# 1  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  81+3  88+3  65+3  60+3  60+3  60+3  65+3  60+3  47+3  47+3  47+3  60+3
# 4  87+3  88+3  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
# 5  82+3  89+3  66+3  63+3  63+3  63+3  66+3  60+3  49+3  49+3  49+3  60+3
#
#    Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0  84.0      95.0       70.0             90.0          86.0     97.0
# 1  84.0      94.0       89.0             81.0          87.0     88.0
# 2  79.0      87.0       62.0             84.0          84.0     96.0
# 4  93.0      82.0       55.0             92.0          82.0     86.0
# 5  81.0      84.0       61.0             89.0          80.0     95.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 0  93.0   94.0        87.0         96.0         91.0          86.0
# 1  81.0   76.0        77.0         94.0         89.0          91.0
# 2  88.0   87.0        78.0         95.0         94.0          90.0
# 4  85.0   83.0        91.0         91.0         78.0          76.0
# 5  83.0   79.0        83.0         94.0         94.0          88.0
#
#    Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  \
# 0  91.0     95.0       95.0     85.0       68.0     72.0     59.0
# 1  87.0     96.0       70.0     95.0       95.0     88.0     79.0
# 2  96.0     94.0       84.0     80.0       61.0     81.0     49.0
# 4  79.0     91.0       77.0     91.0       63.0     90.0     75.0
# 5  95.0     90.0       94.0     82.0       56.0     83.0     66.0
#
#    LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0  94.0       48.0        22.0           94.0         94.0    75.0
# 1  93.0       63.0        29.0           95.0         82.0    85.0
# 2  82.0       56.0        36.0           89.0         87.0    81.0
# 4  91.0       76.0        61.0           87.0         94.0    79.0
# 5  80.0       54.0        41.0           87.0         89.0    86.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0  96.0       33.0     28.0            26.0           6.0       11.0
# 1  95.0       28.0     31.0            23.0           7.0       11.0
# 2  94.0       27.0     24.0            33.0           9.0       9.0
# 4  88.0       68.0     58.0            51.0           15.0      13.0
# 5  91.0       34.0     27.0            22.0           11.0      12.0
#
#    GKKicking  GKPositioning  GKReflexes  cluster
# 0  15.0       14.0           8.0         1
# 1  15.0       14.0           11.0        1
# 2  15.0       15.0           11.0        1
# 4  5.0        10.0           13.0        1
# 5  6.0        8.0            8.0         1

# %%
plt.figure(figsize=[20,10])
plt.scatter(
        cluster1['Overall'],
        cluster1['Jersey Number'],
        color = 'r',
        marker = 'o')  
plt.scatter(
        cluster2['Overall'],
        cluster2['Jersey Number'],
        color = 'y',
        marker = 'o')  
plt.scatter(
        cluster3['Overall'],
        cluster3['Jersey Number'],
        color = 'b',
        marker = 'o')  
plt.scatter(
        cluster4['Overall'],
        cluster4['Jersey Number'],
        color = 'g',
        marker = 'o')  
plt.scatter(
        cluster5['Overall'],
        cluster5['Jersey Number'],
        color = 'purple',
        marker = 'o')  
plt.scatter(
        cluster6['Overall'],
        cluster6['Jersey Number'],
        color = 'pink',
        marker = 'o')  
plt.scatter(
        cluster7['Overall'],
        cluster7['Jersey Number'],
        color = 'hotpink',
        marker = 'o')  
plt.scatter(
        cluster8['Overall'],
        cluster8['Jersey Number'],
        color = 'darkblue',
        marker = 'o')  

plt.scatter(
        cluster9['Overall'],
        cluster9['Jersey Number'],
        color = 'darkorange',
        marker = 'o')  
plt.scatter(
        cluster0['Overall'],
        cluster0['Jersey Number'],
        color = 'tomato',
        marker = 'o')  




plt.title('plotting all cluster ')
plt.xlabel('overal ')
plt.ylabel('jersey number  ')
plt.legend(['cluster 1', 'cluster 2','cluster 3','cluster 4 ','cluster 5','cluster 6','cluster 7','cluster 8','cluster 9','cluster 0'])
plt.grid(True)

# %%
cluster1[['Name','Overall','Jersey Number']].head(10)
# Out:
#                  Name  Overall  Jersey Number
# 0   L. Messi           94       10.0
# 1   Cristiano Ronaldo  94       7.0
# 2   Neymar Jr          92       10.0
# 4   K. De Bruyne       91       7.0
# 5   E. Hazard          91       10.0
# 6   L. Modrić          91       10.0
# 7   L. Suárez          91       9.0
# 10  R. Lewandowski     90       9.0
# 11  T. Kroos           90       8.0
# 12  D. Godín           90       10.0

# %%
cluster3[['Name','Overall','Jersey Number']].head(10)
# Out:
#              Name  Overall  Jersey Number
# 8   Sergio Ramos   91       15.0
# 13  David Silva    90       21.0
# 14  N. Kanté       89       13.0
# 15  P. Dybala      89       21.0
# 21  E. Cavani      89       21.0
# 27  Casemiro       88       14.0
# 30  Isco           88       22.0
# 33  P. Aubameyang  88       14.0
# 35  Marcelo        88       12.0
# 42  S. Umtiti      87       23.0

# %%
plt.scatter(
        cluster1['Overall'],
        cluster1['Jersey Number'],
        color = 'darkblue',
        marker = 'o')   
plt.title('plotting all cluster ')
plt.xlabel('overal ')
plt.ylabel('jersey number  ')
plt.legend(['cluster 1'])
plt.grid(True)

# %%
plt.scatter(
        cluster3['Overall'],
        cluster3['Jersey Number'],
        color = 'tomato',
        marker = 'o')  
plt.title('plotting all cluster ')
plt.xlabel('overal ')
plt.ylabel('jersey number  ')
plt.legend(['cluster 3'])
plt.grid(True)

# %%
fig = plt.figure(figsize=(14,7))

plt.subplot(121)
plt.scatter(
        cluster1['Overall'],
        cluster1['Jersey Number'],
        color = 'tomato',
        marker = 'o') 
plt.subplot(122)
plt.scatter(
        cluster3['Overall'],
        cluster3['Jersey Number'],
        color = 'darkblue',
        marker = 'o')

# %%
cluster1[['Jersey Number','Name','Overall']].head(100)
# Out:
#      Jersey Number               Name  Overall
# 0    10.0           L. Messi           94
# 1    7.0            Cristiano Ronaldo  94
# 2    10.0           Neymar Jr          92
# 4    7.0            K. De Bruyne       91
# 5    10.0           E. Hazard          91
# 6    10.0           L. Modrić          91
# 7    9.0            L. Suárez          91
# 10   9.0            R. Lewandowski     90
# 11   8.0            T. Kroos           90
# 12   10.0           D. Godín           90
# 16   9.0            H. Kane            89
# 17   7.0            A. Griezmann       89
# 20   5.0            Sergio Busquets    89
# 23   10.0           S. Agüero          89
# 24   3.0            G. Chiellini       89
# 25   10.0           K. Mbappé          88
# 26   10.0           M. Salah           88
# 28   10.0           J. Rodríguez       88
# 29   10.0           L. Insigne         88
# 31   10.0           C. Eriksen         88
# 32   7.0            Coutinho           88
# 34   5.0            M. Hummels         88
# 36   11.0           G. Bale            88
# 38   9.0            G. Higuaín         88
# 39   2.0            Thiago Silva       88
# 43   9.0            M. Icardi          87
# 45   6.0            P. Pogba           87
# 47   9.0            R. Lukaku          87
# 51   5.0            J. Vertonghen      87
# 53   4.0            I. Rakitić         87
# 54   3.0            Piqué              87
# 56   11.0           Bernardo Silva     86
# 58   10.0           S. Mané            86
# 59   4.0            V. van Dijk        86
# 60   10.0           R. Sterling        86
# 61   9.0            Roberto Firmino    86
# 62   4.0            R. Varane          86
# 63   6.0            M. Verratti        86
# 65   11.0           Douglas Costa      86
# 68   11.0           M. Reus            86
# 71   2.0            T. Alderweireld    86
# 72   5.0            M. Pjanić          86
# 73   4.0            M. Benatia         86
# 74   10.0           M. Özil            86
# 76   8.0            Iniesta            86
# 79   10.0           Marco Asensio      85
# 83   6.0            Saúl               85
# 85   8.0            D. Alaba           85
# 86   8.0            Koke               85
# 87   9.0            A. Lacazette       85
# 88   4.0            K. Manolas         85
# 90   10.0           Parejo             85
# 91   9.0            Paulinho           85
# 93   7.0            A. Sánchez         85
# 94   8.0            Y. Brahimi         85
# 96   8.0            A. Vidal           85
# 98   9.0            E. Džeko           85
# 99   6.0            S. Khedira         85
# 105  9.0            K. Benzema         85
# 106  3.0            Filipe Luís        85
# 107  4.0            V. Kompany         85
# 108  3.0            Pepe               85
# 109  9.0            Z. Ibrahimović     85
# 114  8.0            Bruno Fernandes    84
# 116  11.0           A. Martial         84
# 118  3.0            Fabinho            84
# 119  5.0            Marquinhos         84
# 121  8.0            Jorginho           84
# 123  2.0            Carvajal           84
# 124  10.0           M. Depay           84
# 125  7.0            H. Son             84
# 129  11.0           J. Cuadrado        84
# 134  4.0            Illarramendi       84
# 135  2.0            K. Walker          84
# 137  7.0            José Callejón      84
# 138  11.0           A. Di María        84
# 142  10.0           E. Banega          84
# 143  6.0            A. Witsel          84
# 145  10.0           Jonas              84
# 148  9.0            Falcao             84
# 151  10.0           A. Gómez           84
# 153  7.0            Quaresma           84
# 154  10.0           A. Robben          84
# 155  11.0           O. Dembélé         83
# 157  7.0            Ronaldo Cabrais    83
# 158  4.0            Josué Chiamulera   83
# 159  9.0            Louri Beretta      83
# 160  3.0            P. Kimpembe        83
# 161  8.0            N. Keïta           83
# 163  8.0            T. Lemar           83
# 167  9.0            T. Werner          83
# 170  9.0            Q. Promes          83
# 173  10.0           Y. Carrasco        83
# 174  7.0            Gerard Moreno      83
# 179  6.0            S. Gnabry          83
# 182  5.0            J. Stones          83
# 183  11.0           Suso               83
# 184  7.0            J. Draxler         83
# 185  8.0            Felipe Anderson    83
# 190  5.0            Allan              83

# %%
cluster3[['Jersey Number','Name','Overall']].head(100)
# Out:
#      Jersey Number                 Name  Overall
# 8    15.0           Sergio Ramos         91
# 13   21.0           David Silva          90
# 14   13.0           N. Kanté             89
# 15   21.0           P. Dybala            89
# 21   21.0           E. Cavani            89
# 27   14.0           Casemiro             88
# 30   22.0           Isco                 88
# 33   14.0           P. Aubameyang        88
# 35   12.0           Marcelo              88
# 42   23.0           S. Umtiti            87
# 44   26.0           K. Koulibaly         87
# 48   17.0           C. Immobile          87
# 49   18.0           Jordi Alba           87
# 50   14.0           D. Mertens           87
# 52   17.0           M. Hamšík            87
# 55   19.0           L. Sané              86
# 64   12.0           Alex Sandro          86
# 66   13.0           T. Müller            86
# 67   19.0           Thiago               86
# 69   14.0           Azpilicueta          86
# 70   19.0           L. Bonucci           86
# 75   25.0           Fernandinho          86
# 78   21.0           S. Milinković-Savić  85
# 80   18.0           N. Fekir             85
# 82   18.0           J. Kimmich           85
# 84   26.0           R. Mahrez            85
# 89   30.0           N. Otamendi          85
# 95   17.0           J. Boateng           85
# 100  19.0           Diego Costa          85
# 101  14.0           R. Nainggolan        85
# 102  29.0           Naldo                85
# 103  14.0           B. Matuidi           85
# 104  23.0           Miranda              85
# 110  23.0           D. Sánchez           84
# 111  24.0           J. Giménez           84
# 112  13.0           Alex Telles          84
# 113  14.0           A. Laporte           84
# 115  15.0           N. Süle              84
# 117  20.0           D. Alli              84
# 120  14.0           William Carvalho     84
# 122  20.0           F. Thauvin           84
# 127  14.0           S. de Vrij           84
# 130  17.0           Iago Aspas           84
# 132  31.0           N. Matić             84
# 136  21.0           I. Gündoğan          84
# 139  17.0           M. Mandžukić         84
# 140  22.0           Willian              84
# 144  18.0           D. Payet             84
# 146  19.0           Sokratis             84
# 150  33.0           Raúl Albiol          84
# 152  15.0           A. Barzagli          84
# 156  33.0           Gabriel Jesus        83
# 162  24.0           C. Tolisso           83
# 164  29.0           K. Coman             83
# 165  20.0           J. Tah               83
# 166  24.0           Anderson Talisca     83
# 168  25.0           A. Rabiot            83
# 169  14.0           L. Goretzka          83
# 171  22.0           H. Ziyech            83
# 172  17.0           Lucas Vázquez        83
# 175  28.0           Felipe               83
# 176  17.0           M. Kovačić           83
# 178  14.0           Manu Trigueros       83
# 181  15.0           S. Savić             83
# 186  27.0           Lucas Moura          83
# 187  22.0           Danilo Pereira       83
# 188  12.0           Nacho Fernández      83
# 191  13.0           F. Acerbi            83
# 192  20.0           Sergi Roberto        83
# 194  21.0           Pizzi                83
# 198  17.0           I. Gueye             83
# 202  15.0           K. Glik              83
# 203  16.0           K. Strootman         83
# 204  28.0           B. Dost              83
# 207  19.0           Luiz Gustavo         83
# 209  30.0           David Luiz           83
# 220  19.0           M. Dembélé           83
# 223  16.0           D. De Rossi          83
# 227  16.0           Rodri                82
# 230  13.0           Rosberto Dourado     82
# 233  18.0           Gelson Martins       82
# 234  17.0           Gonçalo Guedes       82
# 235  14.0           L. Torreira          82
# 236  14.0           Malcom               82
# 238  21.0           L. Hernández         82
# 239  15.0           C. Lenglet           82
# 240  27.0           A. Kramarić          82
# 242  16.0           Dani García          82
# 243  20.0           F. Bernardeschi      82
# 245  15.0           D. Rugani            82
# 248  13.0           A. Romagnoli         82
# 250  17.0           Fred                 82
# 255  22.0           F. Vázquez           82
# 257  16.0           A. Rüdiger           82
# 258  16.0           A. Florenzi          82
# 260  15.0           T. Meunier           82
# 261  26.0           S. Sané              82
# 268  17.0           C. Bakambu           82
# 269  17.0           Pablo Sarabia        82
# 272  23.0           Jonathan Viera       82

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

tracer0 = go.Scatter(
    y= cluster1['Jersey Number'],
    x= cluster1['Overall'],
    text=cluster1['Name'],
    hoverinfo = 'text',
    mode='markers',
    marker=dict(
        size=10,
        color = 'plum', #set color equal to a variable
    )
)

trace1 = go.Scatter(
    y= cluster3['Jersey Number'],
    x= cluster3['Overall'],
    text=cluster3['Name'],
    hoverinfo = 'text',
    mode='markers',
    marker=dict(
        size=10,
        color = 'black', #set color equal to a variable
    )
)
data = [tracer0,trace1]

py.iplot(data, filename='scatter-plot-with-colorscale')
# Out:
# c:\users\blazt\appdata\local\programs\python\python37\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~achmadwildan1122/16.embed" height="525px" width="100%"></iframe>

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

trace1 = go.Scatter(
    y= df['Jersey Number'],
    x= df['Overall'],
    text= df['Name'],
    hoverinfo = 'text',
    mode='markers',
    marker=dict(
        size=10,
        color = model.labels_, #set color equal to a variable
        colorscale='Jet',
    )
)
data = [trace1]

py.iplot(data, filename='scatter-plot-with-colorscale')
# Out:
# c:\users\blazt\appdata\local\programs\python\python37\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~achmadwildan1122/16.embed" height="525px" width="100%"></iframe>
