# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('data.csv')
df.columns[28:54]
df = df.drop(['Unnamed: 0','ID','Photo','Flag','Club Logo','Joined','Special','Loaned From','Body Type', 'Release Clause',
               'Weight','Height','Contract Valid Until','Wage','Value'], axis = 1)
df = df.dropna()

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %% [markdown]
# step: melakukan label encoder nationality agar dapat di olah

# %%
from sklearn.preprocessing import LabelEncoder
labelnational = LabelEncoder()
df['nationalLE'] = labelnational.fit_transform(df['Nationality'])
df.head(15)
# Out:
#                  Name  Age Nationality  Overall  Potential  \
# 0   L. Messi           31   Argentina   94       94
# 1   Cristiano Ronaldo  33   Portugal    94       94
# 2   Neymar Jr          26   Brazil      92       93
# 4   K. De Bruyne       27   Belgium     91       92
# 5   E. Hazard          27   Belgium     91       91
# 6   L. Modrić          32   Croatia     91       91
# 7   L. Suárez          31   Uruguay     91       91
# 8   Sergio Ramos       32   Spain       91       91
# 10  R. Lewandowski     29   Poland      90       90
# 11  T. Kroos           28   Germany     90       90
# 12  D. Godín           32   Uruguay     90       90
# 13  David Silva        32   Spain       90       90
# 14  N. Kanté           27   France      89       90
# 15  P. Dybala          24   Argentina   89       94
# 16  H. Kane            24   England     89       91
#
#                    Club Preferred Foot  International Reputation  Weak Foot  \
# ...

# %% [markdown]
# step : membuat fitur dari overall , buat menjadi categorical dan lakukan encoder

# %%
conditions = [
    (df['Overall'] > 90),
    (df['Overall'] > 80),
    (df['Overall'] > 70),
    (df['Overall'] > 60)
]
choices = ['superb', 'excelent', 'good',' not bad']
df['rating pemain'] = np.select(conditions, choices, default='normal')

# %%
from sklearn.preprocessing import LabelEncoder
labelrating = LabelEncoder()
df['ratingLE'] = labelrating.fit_transform(df['rating pemain'])

# %% [markdown]
# random forest mempelajari pola berdasarkan label yang telah ditentukan (ratingLE) . disini model akan mempelajari data berdasarkan nationality(yg telah diencoding, dan potential ) lalu menentukan apakah bisa menjadi acuan baik tidaknya seorang pemain

# %%
#disini target labelnya adalah overall yang suda dikategorikan, dan akan learning dari age terhadap overall ...

X = df[['nationalLE','Potential']]
y= df['ratingLE']  #targetnya 
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  L. Messi           31   Argentina   94       94
# 1  Cristiano Ronaldo  33   Portugal    94       94
# 2  Neymar Jr          26   Brazil      92       93
# 4  K. De Bruyne       27   Belgium     91       92
# 5  E. Hazard          27   Belgium     91       91
#
#                   Club Preferred Foot  International Reputation  Weak Foot  \
# 0  FC Barcelona         Left           5.0                       4.0
# 1  Juventus             Right          5.0                       4.0
# 2  Paris Saint-Germain  Right          5.0                       5.0
# 4  Manchester City      Right          4.0                       5.0
# 5  Chelsea              Right          4.0                       4.0
#
#    Skill Moves       Work Rate Real Face Position  Jersey Number    LS    ST  \
# 0  4.0          Medium/ Medium  Yes       RF       10.0           88+2  88+2
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# # Menggunakan KNN untuk memodelkan apakah variabel nationality berpengaruh terhadap kehebatan pemain

# %%
from sklearn.neighbors import KNeighborsClassifier

error_rate = []

# Will take some time
for i in range(1,140):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,140),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn.neighbors import KNeighborsClassifier

#k = round((len(a)+ len(b))**.5)
#printk

def nilai_k():
    k=round((len(X_train)+len(X_test))**.5)
    if( k%2 ==0 ):
        return k+1
    else:
        return k
    
print(nilai_k())
# Out:
# 127

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(
        n_neighbors = nilai_k()
)

# %%
#training
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=127, p=2,
#            weights='uniform')

# %%
#accuracy
print(model.score(X_test,y_test)*100,'%')
# Out:
# 63.687735454164915 %

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=600)
rfc.fit(X_train,y_train)
predictions = rfc.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72      2646
#            1       0.48      0.52      0.50       105
#            2       0.56      0.57      0.56      1167
#            3       0.52      0.23      0.31       859
#            4       0.00      0.00      0.00         1
#
#    micro avg       0.62      0.62      0.62      4778
#    macro avg       0.44      0.42      0.42      4778
# weighted avg       0.61      0.62      0.60      4778

# %%
print('knn=',model.score(X_test,y_test)*100,'%')
print('dec.tree=',dtree.score(X_train,y_train)*100,'%')
print('random.forest=',rfc.score(X_train,y_train)*100,'%')
# Out:
# knn= 63.687735454164915 %
# dec.tree= 69.56404736275566 %
# random.forest= 69.56404736275566 %
