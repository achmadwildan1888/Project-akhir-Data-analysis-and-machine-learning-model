# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('data.csv')
df.columns[28:54]
df = df.drop(['Unnamed: 0','ID','Photo','Flag','Club Logo','Joined','Special','Loaned From','Body Type', 'Release Clause',
               'Weight','Height','Contract Valid Until','Wage','Value'], axis = 1)
df = df.dropna()

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %%
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  L. Messi           31   Argentina   94       94
# 1  Cristiano Ronaldo  33   Portugal    94       94
# 2  Neymar Jr          26   Brazil      92       93
# 4  K. De Bruyne       27   Belgium     91       92
# 5  E. Hazard          27   Belgium     91       91
#
#                   Club Preferred Foot  International Reputation  Weak Foot  \
# 0  FC Barcelona         Left           5.0                       4.0
# 1  Juventus             Right          5.0                       4.0
# 2  Paris Saint-Germain  Right          5.0                       5.0
# 4  Manchester City      Right          4.0                       5.0
# 5  Chelsea              Right          4.0                       4.0
#
#    Skill Moves       Work Rate Real Face Position  Jersey Number    LS    ST  \
# 0  4.0          Medium/ Medium  Yes       RF       10.0           88+2  88+2
# ...

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3)

# %%
#sumsquare error & elbow method

ssr=[]
for x in range(1,11):
    model = KMeans(n_clusters=x)
    model.fit(df[['Jersey Number','Overall']])
    ssr.append(model.inertia_)

# %%
#elbow method
plt.plot(
        np.arange(1,11),
        ssr,'b-')
plt.xlabel('range')
plt.ylabel('sumsquare error')
plt.grid(True)

# %%
model.cluster_centers_
# Out:
# array([[71.96052632, 65.10087719],
#        [ 6.50816266, 64.51706738],
#        [19.18118245, 58.26255563],
#        [19.855254  , 75.50243563],
#        [93.11023622, 65.47637795],
#        [28.07278782, 67.32254995],
#        [31.53170359, 56.85179526],
#        [ 7.11802749, 74.27647534],
#        [43.8781575 , 63.31203566],
#        [17.05384922, 66.59194256]])

# %%
model.labels_
# Out:
# array([7, 7, 7, ..., 6, 6, 6])

# %%
#training
model.fit(df[['Jersey Number','Overall']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#predict

prediksi=model.predict(df[['Jersey Number','Overall']])

# %%
df['cluster'] = prediksi
df[df.cluster == 7].head(20)
# Out:
#                    Name  Age  Nationality  Overall  Potential  \
# 97    I. Perišić         29   Croatia      85       85
# 195   K. Kampl           27   Slovenia     83       83
# 484   Y. Rakitskyi       28   Ukraine      80       80
# 748   Daniel Podence     22   Portugal     78       84
# 795   Ricardo Esgaio     25   Portugal     78       80
# 1052  R. Inglese         26   Italy        77       78
# 1101  N. Pejčinović      30   Serbia       77       77
# 1130  K. Mbabu           23   Switzerland  77       83
# 1141  P. Hetemaj         31   Finland      77       77
# 1156  A. Diawara         20   Guinea       77       87
# 1210  Iuri Medeiros      23   Portugal     76       79
# 1244  P. Bargfrede       29   Germany      76       76
# 1291  G. Töre            26   Turkey       76       77
# 1331  A. Paloschi        28   Italy        76       76
# 1528  B. Henrichs        21   Germany      76       84
# 1531  A. Umar            23   Nigeria      76       81
# ...

# %%
df.cluster.nunique()
# Out:
# 10

# %%
df['cluster'] = prediksi
df[df.cluster == 2].head()
# Out:
#              Name  Age     Nationality  Overall  Potential      Club  \
# 208   Giuliano     28   Brazil          83       83         Al Nassr
# 333   M. Brozović  25   Croatia         81       84         Inter
# 759   A. Marušić   25   Montenegro      78       79         Lazio
# 1070  P. Cutrone   20   Italy           77       89         Milan
# 1183  A. Barák     23   Czech Republic  77       84         Udinese
#
#      Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 208   Right          2.0                       3.0        4.0
# 333   Right          2.0                       4.0        3.0
# 759   Right          1.0                       4.0        4.0
# 1070  Right          1.0                       3.0        3.0
# 1183  Left           1.0                       3.0        4.0
#
#            Work Rate Real Face Position  Jersey Number    LS    ST    RS  \
# 208   High/ Medium    No        CAM      77.0           77+2  77+2  77+2
# ...

# %%
df['cluster'] = prediksi
df[df.cluster == 1].head()
# Out:
#              Name  Age   Nationality  Overall  Potential              Club  \
# 5641  I. Mathew    21   Nigeria       69       78         Lillestrøm SK
# 5644  K. Mokotjo   27   South Africa  69       70         Brentford
# 5645  C. Guzmán    24   Mexico        69       74         Monarcas Morelia
# 5650  E. Hackman   23   Ghana         69       76         Portimonense SC
# 5651  Aleix Febas  22   Spain         69       78         Albacete BP
#
#      Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 5641  Right          1.0                       3.0        3.0
# 5644  Right          1.0                       3.0        3.0
# 5645  Right          1.0                       3.0        3.0
# 5650  Right          1.0                       4.0        3.0
# 5651  Right          1.0                       3.0        3.0
#
#            Work Rate Real Face Position  Jersey Number    LS    ST    RS  \
# ...

# %%
df['cluster'] = prediksi
df[df.cluster == 3].head()
# Out:
#               Name  Age Nationality  Overall  Potential                 Club  \
# 356  K. Bellarabi   28   Germany     81       81         Bayer 04 Leverkusen
# 383  O. Toprak      28   Turkey      81       82         Borussia Dortmund
# 431  Raúl           28   Brazil      80       80         SC Braga
# 488  André Almeida  27   Portugal    80       80         SL Benfica
# 532  M. Škrtel      33   Slovakia    80       80         Fenerbahçe SK
#
#     Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 356  Right          3.0                       3.0        4.0
# 383  Right          3.0                       4.0        2.0
# 431  Left           1.0                       3.0        2.0
# 488  Right          2.0                       3.0        3.0
# 532  Right          3.0                       2.0        2.0
#
#           Work Rate Real Face Position  Jersey Number    LS    ST    RS    LW  \
# ...

# %%
#seperate data prediksi
cluster1 = df[df['cluster'] == 1] 
cluster2 = df[df['cluster'] == 2] 
cluster3 = df[df['cluster'] == 3] 
cluster4 = df[df['cluster'] == 4] 
cluster5 = df[df['cluster'] == 5] 
cluster6 = df[df['cluster'] == 6] 
cluster7 = df[df['cluster'] == 7] 
cluster8 = df[df['cluster'] == 8] 
cluster9 = df[df['cluster'] == 9] 
cluster0 = df[df['cluster'] == 0]

# %%
cluster1.head()
# Out:
#              Name  Age   Nationality  Overall  Potential              Club  \
# 5641  I. Mathew    21   Nigeria       69       78         Lillestrøm SK
# 5644  K. Mokotjo   27   South Africa  69       70         Brentford
# 5645  C. Guzmán    24   Mexico        69       74         Monarcas Morelia
# 5650  E. Hackman   23   Ghana         69       76         Portimonense SC
# 5651  Aleix Febas  22   Spain         69       78         Albacete BP
#
#      Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 5641  Right          1.0                       3.0        3.0
# 5644  Right          1.0                       3.0        3.0
# 5645  Right          1.0                       3.0        3.0
# 5650  Right          1.0                       4.0        3.0
# 5651  Right          1.0                       3.0        3.0
#
#            Work Rate Real Face Position  Jersey Number    LS    ST    RS  \
# ...

# %%
plt.figure(figsize=[20,10])
plt.scatter(
        cluster1['Overall'],
        cluster1['Jersey Number'],
        color = 'r',
        marker = 'o')  
plt.scatter(
        cluster2['Overall'],
        cluster2['Jersey Number'],
        color = 'y',
        marker = 'o')  
plt.scatter(
        cluster3['Overall'],
        cluster3['Jersey Number'],
        color = 'b',
        marker = 'o')  
plt.scatter(
        cluster4['Overall'],
        cluster4['Jersey Number'],
        color = 'g',
        marker = 'o')  
plt.scatter(
        cluster5['Overall'],
        cluster5['Jersey Number'],
        color = 'purple',
        marker = 'o')  
plt.scatter(
        cluster6['Overall'],
        cluster6['Jersey Number'],
        color = 'pink',
        marker = 'o')  
plt.scatter(
        cluster7['Overall'],
        cluster7['Jersey Number'],
        color = 'hotpink',
        marker = 'o')  
plt.scatter(
        cluster8['Overall'],
        cluster8['Jersey Number'],
        color = 'darkblue',
        marker = 'o')  

plt.scatter(
        cluster9['Overall'],
        cluster9['Jersey Number'],
        color = 'darkorange',
        marker = 'o')  
plt.scatter(
        cluster0['Overall'],
        cluster0['Jersey Number'],
        color = 'tomato',
        marker = 'o')  




plt.title('plotting all cluster ')
plt.xlabel('overal ')
plt.ylabel('jersey number  ')
plt.legend(['cluster 1', 'cluster 2','cluster 3','cluster 4 ','cluster 5','cluster 6','cluster 7','cluster 8','cluster 9','cluster 0'])
plt.grid(True)

# %%
cluster7[['Name','Overall','Jersey Number']].head(10)
# Out:
#                 Name  Overall  Jersey Number
# 97    I. Perišić      85       44.0
# 195   K. Kampl        83       44.0
# 484   Y. Rakitskyi    80       44.0
# 748   Daniel Podence  78       56.0
# 795   Ricardo Esgaio  78       47.0
# 1052  R. Inglese      77       45.0
# 1101  N. Pejčinović   77       39.0
# 1130  K. Mbabu        77       43.0
# 1141  P. Hetemaj      77       56.0
# 1156  A. Diawara      77       42.0

# %%
cluster6[['Name','Overall','Jersey Number']].head(10)
# Out:
#                Name  Overall  Jersey Number
# 12069  T. Doyle      63       19.0
# 12072  N. Zanellato  63       21.0
# 12078  S. Mensiro    63       23.0
# 12085  K. Nakamura   63       20.0
# 12113  A. Durante    63       22.0
# 12123  M. Gomes      63       23.0
# 12125  E. Hurtado    63       19.0
# 12129  A. Palazzi    63       20.0
# 12131  R. Maeda      63       20.0
# 12136  M. Haas       63       23.0

# %% [markdown]
# penjelasan : ada kemiripan performa antara jersey dengan digit rendah dan digit tinggi

# %%
plt.figure(figsize=[20,10])
plt.scatter(
        cluster8['Overall'],
        cluster8['Jersey Number'],
        color = 'darkblue',
        marker = 'o')    
plt.scatter(
        cluster8['Overall'],
        cluster8['Jersey Number'],
        color = 'tomato',
        marker = 'o')  

plt.title('plotting all cluster ')
plt.xlabel('overal ')
plt.ylabel('jersey number  ')
plt.legend(['cluster 0','cluster 8'])
plt.grid(True)

# %%
plt.scatter(
        cluster8['Overall'],
        cluster8['Jersey Number'],
        color = 'darkblue',
        marker = 'o')   
plt.title('plotting all cluster ')
plt.xlabel('overal ')
plt.ylabel('jersey number  ')
plt.legend(['cluster 8'])
plt.grid(True)

# %%
plt.scatter(
        cluster0['Overall'],
        cluster0['Jersey Number'],
        color = 'tomato',
        marker = 'o')  
plt.title('plotting all cluster ')
plt.xlabel('overal ')
plt.ylabel('jersey number  ')
plt.legend(['cluster 0'])
plt.grid(True)

# %%
cluster0[['Jersey Number','Name','Overall']].head(100)
# Out:
#      Jersey Number                 Name  Overall
# 8    15.0           Sergio Ramos         91
# 13   21.0           David Silva          90
# 14   13.0           N. Kanté             89
# 15   21.0           P. Dybala            89
# 21   21.0           E. Cavani            89
# 27   14.0           Casemiro             88
# 30   22.0           Isco                 88
# 33   14.0           P. Aubameyang        88
# 35   12.0           Marcelo              88
# 42   23.0           S. Umtiti            87
# 44   26.0           K. Koulibaly         87
# 48   17.0           C. Immobile          87
# 49   18.0           Jordi Alba           87
# 50   14.0           D. Mertens           87
# 52   17.0           M. Hamšík            87
# 55   19.0           L. Sané              86
# 66   13.0           T. Müller            86
# 67   19.0           Thiago               86
# 69   14.0           Azpilicueta          86
# 70   19.0           L. Bonucci           86
# ...

# %%
cluster8[['Jersey Number','Name','Overall']].head(100)
# Out:
#       Jersey Number                Name  Overall
# 376   92.0           S. El Shaarawy      81
# 393   87.0           A. Candreva         81
# 684   89.0           S. Feghouli         79
# 758   99.0           Dyego Sousa         78
# 776   87.0           Marcelo Goiano      78
# 782   91.0           D. Zapata           78
# 834   92.0           G. Defrel           78
# 865   86.0           N. Gudelj           78
# 910   99.0           G. Hoarau           77
# 994   99.0           Vágner Love         77
# 1262  88.0           M. Pašalić          76
# 1281  91.0           L. Teodorczyk       76
# 1312  83.0           Gedson Fernandes    76
# 1358  88.0           C. Erkin            76
# 1687  88.0           A. Grassi           75
# 1756  88.0           G. İnler            75
# 1996  87.0           E. Zukanović        75
# 2041  87.0           José Cañas          75
# 2112  87.0           Anselmo             74
# 2139  92.0           A. Chahechouhe      74
# ...

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

tracer0 = go.Scatter(
    y= cluster0['Jersey Number'],
    x= cluster0['Overall'],
    text=cluster0['Name'],
    hoverinfo = 'text',
    mode='markers',
    marker=dict(
        size=10,
        color = 'plum', #set color equal to a variable
    )
)

trace2 = go.Scatter(
    y= cluster7['Jersey Number'],
    x= cluster7['Overall'],
    text=cluster7['Name'],
    hoverinfo = 'text',
    mode='markers',
    marker=dict(
        size=10,
        color = 'black', #set color equal to a variable
    )
)
data = [tracer0,trace2]

py.iplot(data, filename='scatter-plot-with-colorscale')
# Out:
# c:\users\blazt\appdata\local\programs\python\python37\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~achmadwildan1122/16.embed" height="525px" width="100%"></iframe>

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

trace1 = go.Scatter(
    y= df['Jersey Number'],
    x= df['Overall'],
    text= df['Name'],
    hoverinfo = 'text',
    mode='markers',
    marker=dict(
        size=10,
        color = model.labels_, #set color equal to a variable
        colorscale='Rainbow',
    )
)
data = [trace1]

py.iplot(data, filename='scatter-plot-with-colorscale')
# Out:
# c:\users\blazt\appdata\local\programs\python\python37\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~achmadwildan1122/16.embed" height="525px" width="100%"></iframe>
